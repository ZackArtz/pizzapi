# %% [markdown]
# ### Import Pizza API and define the Customer

# %%
from pizzapy import *

# %%
customer = Customer('First Name', 'Last Name', 'email', 'phone number', 'Address')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-8e69ec805493> in <module>
# ----> 1 customer = Customer('First Name', 'Last Name', 'email', 'phone number', 'Address')
#
# ~/dev/pizza/pizzapi/pizzapy/customer.py in __init__(self, fname, lname, email, phone, address)
#       9         self.email = email.strip()
#      10         self.phone = str(phone).strip()
# ---> 11         self.address = Address(*address.split(','))
#      12
#      13     def __repr__(self):
#
# TypeError: __init__() missing 1 required positional argument: 'city'

# %%
customer
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cdb60202a554> in <module>
# ----> 1 customer
#
# NameError: name 'customer' is not defined

# %% [markdown]
# ### Find local Dominos

# %%
my_local_dominos = StoreLocator.find_closest_store_to_customer(customer)

# %% [markdown]
# ### Search the menu

# %%
menu = my_local_dominos.get_menu()

# %%
menu.search(Name='Banana')
# Out:
# SIDBAN Side Banana Peppers $0.69

# %% [markdown]
# ### Begin the order process

# %%
order = Order.begin_customer_order(customer, my_local_dominos)
order.add_item('12TPFEAST')
order.add_item('20BCOKE')
# Out:
# {'Code': '20BCOKE',
#  'FlavorCode': '',
#  'ImageCode': '20BCOKE',
#  'Local': False,
#  'Name': '20oz Bottle Coke®',
#  'Price': '2.49',
#  'ProductCode': 'F_COKE',
#  'SizeCode': '20OZB',
#  'Tags': {'DefaultSides': '', 'DefaultToppings': ''},
#  'AllowedCookingInstructions': '',
#  'DefaultCookingInstructions': '',
#  'Prepared': False,
#  'Pricing': {'Price2-4': '2.49',
#   'Price1-0': '2.49',
#   'Price1-3': '2.49',
#   'Price2-3': '2.49',
#   'Price1-4': '2.49',
#   'Price2-2': '2.49',
#   'Price1-1': '2.49',
#   'Price2-1': '2.49',
#   'Price1-2': '2.49',
#   'Price2-0': '2.49'},
#  'Surcharge': '0',
#  'ID': 1,
#  'isNew': True,
#  'Qty': 1,
#  'AutoRemove': False}

# %%
card = CreditCard('numbers', 'numbers', 'numbers', 'numbers')

# %% [markdown]
# *not real credit card details, obv*

# %%
# order.place()
# Out:
# {'Order': {'Address': {'Street': '950 Laki Rd',
#    'City': 'Honolulu',
#    'Region': 'HI',
#    'PostalCode': '96817',
#    'Type': 'House',
#    'StreetNumber': '950',
#    'StreetName': 'LAKI RD'},
#   'Coupons': [],
#   'CustomerID': '',
#   'Extension': '',
#   'OrderChannel': 'OLO',
#   'OrderID': 'hGZM9QH3S40v4iLKfWfj',
#   'NoCombine': True,
#   'OrderMethod': 'Web',
#   'Payments': [{'Type': 'Cash'}],
#   'Market': 'UNITED_STATES',
#   'Currency': 'USD',
#   'ServiceMethod': 'Delivery',
#   'Tags': {},
#   'Version': '1.0',
#   'SourceOrganizationURI': 'order.dominos.com',
#   'LanguageCode': 'en',
#   'Partners': {},
#   'NewUser': True,
#   'metaData': {},
#   'BusinessDate': '2019-10-25',
#   'EstimatedWaitMinutes': '26-41',
#   'AmountsBreakdown': {'FoodAndBeverage': '19.54',
#    'Adjustment': '0.00',
#    'Surcharge': '0.00',
#    'DeliveryFee': '5.99',
#    'Tax': 1.19,
#    'Tax1': 1.19,
#    'Tax2': 0,
#    'Bottle': 0.06,
#    'Customer': 26.72,
# ...

# %% [markdown]
# ### Place the order

# %% [markdown]
# # DO NOT UNCOMMENT UNLESS YOU WANT TO ORDER PIZZA. YOU HAVE BEEN WARNED

# %%
#my_local_dominos.place_order(order, customer)
